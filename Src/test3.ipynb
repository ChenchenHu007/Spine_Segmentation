# %%
import matplotlib.pyplot as plt
import SimpleITK as sitk
import pandas as pd
from DataLoader.dataloader_VertebraeSegmengtation import landmark_extractor, read_data,pre_processing
from utils.heatmap_generator import HeatmapGenerator
from utils.processing import crop_center, normalize, crop

import cv2
import random
import numpy as np

# %%
path = '/home/minghao/Desktop/Spine_Segmentation_new_data/Spine_Segmentation/Case2'
dict_images = read_data(path)

# %%
MR, heatmap, index = pre_processing(dict_images)
MR.shape
# Out:
# (1, 12, 160, 160)

# %%
plt.imshow(MR[0][6], cmap='gray')

# %%
heatmap.shape
# Out:
# (1, 12, 160, 160)

# %%
plt.imshow(heatmap[0][6], cmap='gray')

# %%
index
# Out:
# 6
